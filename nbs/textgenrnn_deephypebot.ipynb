# %%
from textgenrnn.textgenrnn import textgenrnn, utils
# Out:
# Using TensorFlow backend.

# %%
import os
import pandas as pd

BASE_DIR = os.getcwd()
reviews_f = 'reviews_and_metadata'
DATA_DIR = os.path.join(BASE_DIR, '..', 'datasets', f'{reviews_f}_5yrs')

train_f = os.path.join(DATA_DIR, 'train.json')
train_df = pd.read_json(train_f)
print(f'num_reviews: {len(train_df)}')
train_df.head()
# Out:
# num_reviews: 15900
#    acousticness         artist               artist_id  \
# 0        0.6370   Cass McCombs  2iUVQjheBnvOt8vaBrxXJz
# 1        0.0151     Disclosure  6nS5roXSAGhTGr34W6n7Et
# 2        0.2560      Klangstof  25lIYhqIj0R1AnnmqsTrtO
# 3        0.3670    Skizzy Mars  00Z3UDoAQwzvGu13HoAM7J
# 4        0.7000  Promises Ltd.  2JgUCWMkArdLIENeaJcJ0Y
#
#                                       audio_features           author  \
# 0  {'danceability': 0.485, 'energy': 0.5740000000...     Zach Frimmel
# 1  {'danceability': 0.502, 'energy': 0.732, 'key'...  Clayton Warwick
# 2  {'danceability': 0.491, 'energy': 0.45, 'key':...             None
# 3  {'danceability': 0.5640000000000001, 'energy':...             None
# 4  {'danceability': 0.645, 'energy': 0.734, 'key'...             None
#
#                                              content  \
# 0  photo by Rachel Pony Cassells\nEvery Monday th...
# 1  Disclosure\nLatch (TEEMID X Daniela Andrade Ed...
# 2  How does one know when the love is real? What ...
# 3  I still remember when I was first convinced to...
# 4  "Days of Lavender" becomes a haunting, shiftin...
#
#                                    content_sentences  danceability  \
# 0  [photo by Rachel Pony Cassells Every Monday th...         0.485
# 1  [<artist> <song_title, >, There's no doubt tha...         0.502
# 2  [How does one know when the love is real?, Wha...         0.491
# 3  [I still remember when I was first convinced t...         0.564
# 4  ["Days of Lavender" becomes a haunting, shifti...         0.645
#
#              date_published  dek     ...             sitename  \
# 0  2016-10-19T00:00:00.000Z  NaN     ...            KEXP Blog
# 1  2014-08-06T00:00:00.000Z  NaN     ...      The Music Ninja
# 2                      None  NaN     ...        Indie Shuffle
# 3                      None  NaN     ...        Indie Shuffle
# 4                      None  NaN     ...        Indie Shuffle
#
#                                  song_title speechiness  \
# 0                            Opposite House      0.0295
# 1  Latch (TEEMID X Daniela Andrade Edition)      0.1680
# 2                                   Everest      0.0297
# 3                                   Be Lazy      0.3460
# 4           Days Of Lavender (AMTRAC REMIX)      0.0439
#
#                                       spotify_genres              spotify_id  \
# 0  [alternative rock, art pop, chamber pop, dream...  2XpsvLcddOSFanKBCZCEBR
# 1                       [house, pop, tropical house]  1BltsyC5W3SAABdxyrDXwi
# 2                                       [vapor soul]  6i7n4C2mSx6WEmfFEhPWYf
# 3                                [pop, pop rap, rap]  0qZDyzZkeFfPseTXUPnH4C
# 4                                       [vapor soul]  2AtsONzSPfEHzeGpXaqNEQ
#
#      tempo time_signature total_pages  valence  word_count
# 0  153.076            4.0           1   0.6110         487
# 1  122.025            4.0           1   0.5360         192
# 2  153.964            4.0           1   0.3080         113
# 3   99.228            4.0           1   0.4460         185
# 4  114.976            4.0           1   0.0306         100
#
# [5 rows x 46 columns]

# %%
import re
import unicodedata

# Turn a Unicode string to plain ASCII, thanks to http://stackoverflow.com/a/518232/2809427
def unicode_to_ascii(s):
    return ''.join(
        c for c in unicodedata.normalize(u'NFD', s)
        if unicodedata.category(c) != u'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalize_string(s):
    s = unicode_to_ascii(s.lower().strip())
    s = re.sub(r"'", r"", s)
    s = re.sub(r"([.!?])", r" \1", s)
    #s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"[^\w]", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip().lstrip().rstrip()
    return s

def normalize(line):
    l = line.strip().lstrip().rstrip()
    return normalize_string(l)

min_gen_length = 10
max_gen_length = 200

sents = [normalize(sent) for ss in train_df.content_sentences for sent in ss if min_gen_length < len(sent.split()) < max_gen_length]
sents[:10]
# Out:
# ['photo by rachel pony cassells every monday through friday we deliver a different song as part of our song of the day podcast subscription',
#  'this podcast features exclusive kexp in studio performances unreleased songs and recordings from independent artists that our djs think you should hear',
#  'todays song featured on the midday show with cheryl waters is song_title by artist from his eight studio record and debut on anti records entitled mangy love',
#  'artist has been humbly hiding out under the underground with tip of the iceberg fame for fifteen years now',
#  'aside from his melodious easy listening psych rock that religiously flirts with reverb and lyrical slow jams the la based musician is known for being reclusive but respected mellow but meticulous dissent prone but decent',
#  'with eight studio albums now to his name the last five previously on domino records hes recently released mangy love out on anti records which is yet another peak of perfection in his seemingly valley less career',
#  'a song like song_title demonstrates the established smooth sound and aphoristic gravitas that artist has been chasing and mastering for handfuls of years',
#  'hes somehow able to turn the rock reggae pop psych and alt country genres and cultures on their heads and flip them back over to create his own shaken up style that incorporates r b like humidity jazzy hooks twinkling piano atmospheric synth vulnerable singing and earnest lyricism',
#  'his brut vocal style is balanced with his honest honeyed crooning and his vocal range spans two octaves on a lot songs',
#  'to boot his virtuoso musicality and musicianship are virtually undetectable due to them being so second nature to him']

# %%
train_text_f = os.path.join(DATA_DIR, 'train.txt')

sents_out = '\n'.join(sents)
sents_out[:2000]
# Out:
# 'photo by rachel pony cassells every monday through friday we deliver a different song as part of our song of the day podcast subscription\nthis podcast features exclusive kexp in studio performances unreleased songs and recordings from independent artists that our djs think you should hear\ntodays song featured on the midday show with cheryl waters is song_title by artist from his eight studio record and debut on anti records entitled mangy love\nartist has been humbly hiding out under the underground with tip of the iceberg fame for fifteen years now\naside from his melodious easy listening psych rock that religiously flirts with reverb and lyrical slow jams the la based musician is known for being reclusive but respected mellow but meticulous dissent prone but decent\nwith eight studio albums now to his name the last five previously on domino records hes recently released mangy love out on anti records which is yet another peak of perfection in his seemingly valley less career\na song like song_title demonstrates the established smooth sound and aphoristic gravitas that artist has been chasing and mastering for handfuls of years\nhes somehow able to turn the rock reggae pop psych and alt country genres and cultures on their heads and flip them back over to create his own shaken up style that incorporates r b like humidity jazzy hooks twinkling piano atmospheric synth vulnerable singing and earnest lyricism\nhis brut vocal style is balanced with his honest honeyed crooning and his vocal range spans two octaves on a lot songs\nto boot his virtuoso musicality and musicianship are virtually undetectable due to them being so second nature to him\none of anti records public taglines is real musicians creating records on their own terms which sums up artist pretty well\nhe collaborates with whoever he wants like angel olsen blake mills and nineteen others on mangy love and hes not afraid to speak his mind\nmoreover it doesnt take a laundry list of venerable musicians selecting their'

# %%
with open(train_text_f, 'w') as f:
    f.write(sents_out)

# %%
model_cfg = {
    'rnn_size': 128,
    'rnn_layers': 4,
    'rnn_bidirectional': True,
    'max_length': 10,#5,#300,
    'max_words': 500000,
    'dim_embeddings': 300,
    'word_level': True,
}

train_cfg = {
    'line_delimited': True,
    'num_epochs': 10,#1
    'gen_epochs': 2,#1,#0
    'sample_epochs': 1,
    'batch_size': 512,
    'train_size': 1.0,#0.8,
    'dropout': 0.1,
    'max_gen_length': 200,
    'validation': False,#True,
    'is_csv': False
}

# %%
from keras.callbacks import Callback

class save_loss(Callback):
    def __init__(self, losses):
        self.losses = losses

    def on_epoch_end(self, epoch, logs):
        self.losses.append(logs['loss'])

# %%
textgen = textgenrnn(name=reviews_f)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

losses = []

train_function(
    file_path=str(train_text_f),
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=train_cfg['batch_size'],
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    max_gen_length=train_cfg['max_gen_length'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=model_cfg['dim_embeddings'],
    word_level=model_cfg['word_level'],
    callbacks=[save_loss(losses)])
# Out:
# 84,642 texts collected.
# Training new model w/ 4-layer, 128-cell Bidirectional LSTMs
# Training on 1,970,991 word sequences.
# Epoch 1/10
# 3849/3849 [==============================] - 176s 46ms/step - loss: 5.1569
# Epoch 2/10
# 3849/3849 [==============================] - 170s 44ms/step - loss: 4.5536
# ####################
# Temperature: 0.2
# ####################
# the track is a slow burner that is so sultry and soulful that is simply stunning
#
# the track is a slow burner that is so beautiful and catchy
#
# the track is a slow burner that showcases the bands ability to blend the of the original and the chorus is the perfect soundtrack for the summer
#
# ####################
# Temperature: 0.5
# ####################
# the track is one of the most fragile parts of the track that the band have taken a remix of artist s single
#
# the track is a great upbeat track that is simply beautiful and catchy as it does
#
# the track is a beautiful piece of electronica that is steeped in emotion and emotion
#
# ####################
# Temperature: 1.0
# ####################
# i up a lot is there to be coming out of this year
#
# the original super funky groovy track reads turns about what put a left field part of the summer
#
# in the album also set the in the shape of that alone records attending 9 30
#
# Epoch 3/10
# 3849/3849 [==============================] - 172s 45ms/step - loss: 4.2799
# Epoch 4/10
# 3849/3849 [==============================] - 172s 45ms/step - loss: 4.0741
# ####################
# Temperature: 0.2
# ####################
# the track is a slow burn and a little bit of a surprise then
#
# the track is a great addition to the collection of songs
#
# the track is a simple yet simple acoustic song about a love affair
#
# ####################
# Temperature: 0.5
# ####################
# i am super excited to see what he has in store for us
#
# the track is a collaboration with the brazilian poet who is produced by the always talented artist
#
# the track has a bit of a funky bass groove and a vocal sample
#
# ####################
# Temperature: 1.0
# ####################
# directed by in a rubble kings scenes off dying beach with the weeknd
#
# earlier this week wet released the first single off lyk dis fine
#
# following last years single layers peel wildly peel of layers and changes the mood of his latest worldwide smash
#
# Epoch 5/10
# 3849/3849 [==============================] - 170s 44ms/step - loss: 3.8964
# Epoch 6/10
# 3849/3849 [==============================] - 169s 44ms/step - loss: 3.7304
# ####################
# Temperature: 0.2
# ####################
# the track is a buoyant neo disco groover that features the vocal talents of sam sure
#
# the track is a beautiful blend of indie pop and rock
#
# the track is a buoyant neo disco pop gem that features vocals from fellow dmv artist artist
#
# ####################
# Temperature: 0.5
# ####################
# i am pretty excited to see what else the band have to offer
#
# the track is a funky and joyful little number which features the vocal talents of george maple
#
# the third single from the album is the first taste of his forthcoming debut ep due out later this year
#
# ####################
# Temperature: 1.0
# ####################
# computer on is a tropical guitar rock and with moody piano and bass notes this time around a tune
#
# big sean has taking artist to artist s usual electronic dance sound
#
# quite urgent can be its he said about the pairs first wishing had broken in the family of neon icon it is pretty easy to move even as by dance genius
#
# Epoch 7/10
# 3849/3849 [==============================] - 169s 44ms/step - loss: 3.5701
# Epoch 8/10
# 3849/3849 [==============================] - 169s 44ms/step - loss: 3.4206
# ####################
# Temperature: 0.2
# ####################
# the track is a slow burning ballad that builds into a crescendo that is sure to bring you to the beach
#
# the song is a slow burning ballad that builds into a crescendo that is incredibly addictive
#
# the song is a slow burn of 80s influenced pop and the production
#
# ####################
# Temperature: 0.5
# ####################
# the remix is a haunting dreamy tune that will make your heart boost your attention
#
# i have a feeling this one will be a big step for the rest of the summer
#
# the album is out on february 25 via greco roman city slang
#
# ####################
# Temperature: 1.0
# ####################
# it have you ever sat very quietly with closed eyesand watched the movement of your own thinking have you watched your mind working or rather will your mind watched itself in operation just to see what your thoughts is what your feelings are how you look at the trees at the flowers at the birds at people how you respond to a suggestion or react to a new idea have you ever done this
#
# keeping me wondering what he did with a tune so why this isnt too right right
#
# we are ready to announce that its sound at its core with its shadows precision and vocal to get you far off when you move
#
# Epoch 9/10
# 3849/3849 [==============================] - 169s 44ms/step - loss: 3.2677
# Epoch 10/10
# 3849/3849 [==============================] - 169s 44ms/step - loss: 3.1262
# ####################
# Temperature: 0.2
# ####################
# the track is a slow burner with a downtempo rhythm and smooth vocals
#
# the track is a slow burner with a smooth bassline and a driving beat
#
# the track is a slow burner with a downtempo rhythm and an epic build up to the drop
#
# ####################
# Temperature: 0.5
# ####################
# the song is a slow burner with plenty of more dance friendly and welcoming songwriting
#
# the song is a great song about the happiness of another person
#
# its a song about fleeting moments and how we let past feelings the possibility for good things to happen
#
# ####################
# Temperature: 1.0
# ####################
# his wonderfully catchy and interesting english coast will follow up a string of special live shows to date and theyre fully formed in the edm world
#
# more besides inspiration this noise energy is well suited to soundtrack us to the next level
#
# and it was truly worth of the work on his own

# %%
losses
# Out:
# [5.156938241283192,
#  4.553611818181288,
#  4.279892824940571,
#  4.074083189804481,
#  3.896409230530804,
#  3.730400722904557,
#  3.5700648325268216,
#  3.420578568469211,
#  3.267748231360063,
#  3.126224206249012]

# %%
textgen.generate_samples(n=10)
# Out:
# ####################
# Temperature: 0.2
# ####################
# the track is a slow burner with a smooth bassline and a driving beat
#
# the song is a slow burner with a downtempo beat and smooth vocals
#
# the song is a slow burner with a downtempo pulse that is so danceable
#
# the track is a slow burner with a smooth bassline and a driving beat
#
# the track is a very special place to start a project
#
# the track is a very chill piece of work which builds up to a euphoric climax
#
# the track is a slow burner with a downtempo beat that is surely going to capture the atmosphere of the original
#
# the song is a slow burner with a downtempo rhythm and a very lush vibe
#
# the track is a slow burner with a smooth bassline and a driving beat
#
# the track is a slow burner with a downtempo beat and a smooth house groove
#
# ####################
# Temperature: 0.5
# ####################
# the track is a soft but textured vibe with a driving beat that makes the track more upbeat than the original
#
# the way she human and fall into the mantra repeats
#
# the track is called song _ title and it is a collaboration between two of our favorite artists and some of our favorite artists in the game
#
# with the release of his debut lp artist has shared the first single from his upcoming release song _ title
#
# the song is about the feeling of being and being alone in your first store because it looks like it was made available to buy on itunes
#
# the song is about spending time and time holding onto your hand for a few minutes
#
# its a song about fleeting moments and how we let past feelings we are to the sky
#
# the track is a first single released on the bands upcoming album
#
# the song is about experiencing love through a haze like youre seeing yourself from a magic moment of pure bliss
#
# to celebrate the release of the ep artist has shared the first single from her forthcoming debut album
#
# ####################
# Temperature: 1.0
# ####################
# literally a and kitchen with song _ title an instrumental and sentimental song sounding as exposure on this one
#
# a pounding edm thats pretty sure youre going to be incredibly well aware of this one
#
# my favorite song ever to come but artist didnt have youd always do that as well
#
# the frenetic pace is subtle and the topic of being able to river
#
# our editorial newsletter is your ticket to upcoming shows and free stuff
#
# theres a whimsical air about escape which leaves you with another sensation of her most of always nostalgia
#
# both been a long instrumental and a half ago a repeat with those atop sprawling black beatles esque vocals both no okay
#
# artist s new single dream off her upcoming ep proof enough for jagjaguwar
#
# given a smooth kick back and forth plucks and artist s bouncy production
#
# with the same clever character that it is probably in tact yet very well yet very well responsible for all of you
